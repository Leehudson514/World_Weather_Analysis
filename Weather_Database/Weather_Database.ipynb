# %% [markdown]
# # Challenge part 1

# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests
import time
from datetime import datetime

# Import the API key.
from Config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

set_count = 1
record_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | tiznit
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | les escoumins
# Processing Record 6 of Set 1 | vila do maio
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | laguna
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | zavetnoye
# Processing Record 14 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 1 | alofi
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | mehran
# Processing Record 18 of Set 1 | mungwi
# Processing Record 19 of Set 1 | college
# Processing Record 20 of Set 1 | jizan
# Processing Record 21 of Set 1 | beloha
# Processing Record 22 of Set 1 | moindou
# Processing Record 23 of Set 1 | yarovoye
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | nanortalik
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | hamilton
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | saint-louis
# Processing Record 30 of Set 1 | uvarovka
# Processing Record 31 of Set 1 | gigmoto
# Processing Record 32 of Set 1 | vanavara
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | port hardy
# Processing Record 37 of Set 1 | manacapuru
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | bengkulu
# Processing Record 42 of Set 1 | ilulissat
# Processing Record 43 of Set 1 | vardo
# Processing Record 44 of Set 1 | sitka
# Processing Record 45 of Set 1 | novyy urengoy
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 1 | morant bay
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | dingle
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | zalesovo
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | klaksvik
# Processing Record 6 of Set 2 | sao borja
# Processing Record 7 of Set 2 | sorland
# Processing Record 8 of Set 2 | chokwe
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | westport
# Processing Record 11 of Set 2 | aklavik
# Processing Record 12 of Set 2 | vostok
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 2 | primorsko-akhtarsk
# Processing Record 16 of Set 2 | byron bay
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | shelburne
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | tiksi
# Processing Record 22 of Set 2 | mangochi
# Processing Record 23 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 24 of Set 2 | mwene-ditu
# Processing Record 25 of Set 2 | lasa
# Processing Record 26 of Set 2 | lompoc
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | marzuq
# Processing Record 29 of Set 2 | amberley
# Processing Record 30 of Set 2 | barrow
# Processing Record 31 of Set 2 | kodiak
# Processing Record 32 of Set 2 | lavrentiya
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | zemio
# Processing Record 35 of Set 2 | xuchang
# Processing Record 36 of Set 2 | baykit
# Processing Record 37 of Set 2 | mataura
# Processing Record 38 of Set 2 | agropoli
# Processing Record 39 of Set 2 | xai-xai
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | san buenaventura
# Processing Record 42 of Set 2 | ikot ekpene
# Processing Record 43 of Set 2 | lodwar
# Processing Record 44 of Set 2 | port blair
# Processing Record 45 of Set 2 | ixtapa
# Processing Record 46 of Set 2 | sokoni
# Processing Record 47 of Set 2 | victoria
# Processing Record 48 of Set 2 | sao joao da barra
# Processing Record 49 of Set 2 | rawicz
# Processing Record 50 of Set 2 | ostrovnoy
# Processing Record 1 of Set 3 | torbay
# Processing Record 2 of Set 3 | saldanha
# Processing Record 3 of Set 3 | hovd
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | albany
# Processing Record 6 of Set 3 | lata
# Processing Record 7 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 3 | beringovskiy
# Processing Record 9 of Set 3 | busselton
# Processing Record 10 of Set 3 | port lavaca
# Processing Record 11 of Set 3 | the valley
# Processing Record 12 of Set 3 | katsuura
# Processing Record 13 of Set 3 | stykkisholmur
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | wieliczka
# Processing Record 16 of Set 3 | yellowknife
# Processing Record 17 of Set 3 | kalmunai
# Processing Record 18 of Set 3 | luderitz
# Processing Record 19 of Set 3 | padang
# Processing Record 20 of Set 3 | gorontalo
# Processing Record 21 of Set 3 | kununurra
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | turayf
# Processing Record 24 of Set 3 | manggar
# Processing Record 25 of Set 3 | gat
# Processing Record 26 of Set 3 | mehamn
# Processing Record 27 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 29 of Set 3 | hermanus
# Processing Record 30 of Set 3 | treinta y tres
# Processing Record 31 of Set 3 | qaanaaq
# Processing Record 32 of Set 3 | ferrol
# Processing Record 33 of Set 3 | esperance
# Processing Record 34 of Set 3 | bone
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | hirara
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | quatre cocos
# Processing Record 39 of Set 3 | ulaanbaatar
# Processing Record 40 of Set 3 | talnakh
# Processing Record 41 of Set 3 | korla
# Processing Record 42 of Set 3 | matamoros
# Processing Record 43 of Set 3 | new norfolk
# Processing Record 44 of Set 3 | batagay
# Processing Record 45 of Set 3 | margate
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | labuhan
# Processing Record 48 of Set 3 | haines junction
# Processing Record 49 of Set 3 | medicine hat
# Processing Record 50 of Set 3 | kavieng
# Processing Record 1 of Set 4 | kaitangata
# Processing Record 2 of Set 4 | tautira
# Processing Record 3 of Set 4 | havre-saint-pierre
# Processing Record 4 of Set 4 | kuminskiy
# Processing Record 5 of Set 4 | galesong
# Processing Record 6 of Set 4 | santa maria
# Processing Record 7 of Set 4 | broken hill
# Processing Record 8 of Set 4 | tinaquillo
# Processing Record 9 of Set 4 | khasan
# Processing Record 10 of Set 4 | bethel
# Processing Record 11 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 4 | latung
# Processing Record 13 of Set 4 | bambous virieux
# Processing Record 14 of Set 4 | bredasdorp
# Processing Record 15 of Set 4 | longyearbyen
# Processing Record 16 of Set 4 | asyut
# Processing Record 17 of Set 4 | kysyl-syr
# Processing Record 18 of Set 4 | port hawkesbury
# Processing Record 19 of Set 4 | poykovskiy
# Processing Record 20 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 4 | saint-pierre
# Processing Record 22 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 4 | mount gambier
# Processing Record 24 of Set 4 | vestmanna
# Processing Record 25 of Set 4 | charters towers
# Processing Record 26 of Set 4 | iowa city
# Processing Record 27 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 4 | tahara
# Processing Record 29 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 30 of Set 4 | rundu
# Processing Record 31 of Set 4 | solnechnyy
# Processing Record 32 of Set 4 | puerto ayora
# Processing Record 33 of Set 4 | verkhniye tatyshly
# Processing Record 34 of Set 4 | paita
# Processing Record 35 of Set 4 | nara
# Processing Record 36 of Set 4 | thompson
# Processing Record 37 of Set 4 | okhotsk
# Processing Record 38 of Set 4 | nadym
# Processing Record 39 of Set 4 | hilo
# Processing Record 40 of Set 4 | frankenberg
# Processing Record 41 of Set 4 | kutum
# Processing Record 42 of Set 4 | meulaboh
# Processing Record 43 of Set 4 | burnie
# Processing Record 44 of Set 4 | lagoa
# Processing Record 45 of Set 4 | sonqor
# Processing Record 46 of Set 4 | baglung
# Processing Record 47 of Set 4 | tres arroyos
# Processing Record 48 of Set 4 | tomatlan
# Processing Record 49 of Set 4 | chuy
# Processing Record 50 of Set 4 | kotelnikovo
# Processing Record 1 of Set 5 | porto nacional
# Processing Record 2 of Set 5 | tahta
# Processing Record 3 of Set 5 | pocone
# Processing Record 4 of Set 5 | leticia
# Processing Record 5 of Set 5 | gravdal
# Processing Record 6 of Set 5 | faya
# Processing Record 7 of Set 5 | saurimo
# Processing Record 8 of Set 5 | thyboron
# Processing Record 9 of Set 5 | saint-joseph
# Processing Record 10 of Set 5 | hauterive
# Processing Record 11 of Set 5 | kisangani
# Processing Record 12 of Set 5 | brae
# Processing Record 13 of Set 5 | tigre
# Processing Record 14 of Set 5 | comarapa
# Processing Record 15 of Set 5 | yuanping
# Processing Record 16 of Set 5 | hannibal
# Processing Record 17 of Set 5 | vallenar
# Processing Record 18 of Set 5 | altay
# Processing Record 19 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 5 | santa cruz
# Processing Record 21 of Set 5 | krasnoselkup
# Processing Record 22 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 5 | black river
# Processing Record 24 of Set 5 | sao joao batista
# Processing Record 25 of Set 5 | hasaki
# Processing Record 26 of Set 5 | barroualie
# City not found. Skipping...
# Processing Record 27 of Set 5 | nome
# Processing Record 28 of Set 5 | perpignan
# Processing Record 29 of Set 5 | takestan
# Processing Record 30 of Set 5 | portland
# Processing Record 31 of Set 5 | pangkalanbuun
# Processing Record 32 of Set 5 | yongan
# Processing Record 33 of Set 5 | kathu
# Processing Record 34 of Set 5 | sao lourenco do oeste
# Processing Record 35 of Set 5 | north bend
# Processing Record 36 of Set 5 | hami
# Processing Record 37 of Set 5 | toamasina
# Processing Record 38 of Set 5 | mosetse
# Processing Record 39 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 5 | georgetown
# Processing Record 41 of Set 5 | mangai
# Processing Record 42 of Set 5 | alihe
# Processing Record 43 of Set 5 | nosy varika
# Processing Record 44 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 5 | magadan
# Processing Record 46 of Set 5 | cherdyn
# Processing Record 47 of Set 5 | bereda
# Processing Record 48 of Set 5 | arraial do cabo
# Processing Record 49 of Set 5 | nizhnevartovsk
# Processing Record 50 of Set 5 | wanning
# Processing Record 1 of Set 6 | lorengau
# Processing Record 2 of Set 6 | bahir dar
# Processing Record 3 of Set 6 | dzhebariki-khaya
# Processing Record 4 of Set 6 | saint-augustin
# Processing Record 5 of Set 6 | dubuque
# Processing Record 6 of Set 6 | nouadhibou
# Processing Record 7 of Set 6 | reconquista
# Processing Record 8 of Set 6 | egvekinot
# Processing Record 9 of Set 6 | cervo
# Processing Record 10 of Set 6 | chimore
# Processing Record 11 of Set 6 | chapais
# Processing Record 12 of Set 6 | gazanjyk
# Processing Record 13 of Set 6 | ingham
# Processing Record 14 of Set 6 | preobrazheniye
# Processing Record 15 of Set 6 | coquimbo
# Processing Record 16 of Set 6 | naze
# Processing Record 17 of Set 6 | ampanihy
# Processing Record 18 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 6 | fare
# Processing Record 21 of Set 6 | bonthe
# Processing Record 22 of Set 6 | shilka
# Processing Record 23 of Set 6 | mpika
# Processing Record 24 of Set 6 | andenes
# Processing Record 25 of Set 6 | darnah
# Processing Record 26 of Set 6 | boyolangu
# Processing Record 27 of Set 6 | lyskovo
# Processing Record 28 of Set 6 | paamiut
# Processing Record 29 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 6 | curaca
# Processing Record 31 of Set 6 | francisco beltrao
# Processing Record 32 of Set 6 | sechura
# Processing Record 33 of Set 6 | caravelas
# Processing Record 34 of Set 6 | girau do ponciano
# Processing Record 35 of Set 6 | berea
# Processing Record 36 of Set 6 | muroto
# Processing Record 37 of Set 6 | dong hoi
# Processing Record 38 of Set 6 | lebu
# Processing Record 39 of Set 6 | vedaranniyam
# City not found. Skipping...
# Processing Record 40 of Set 6 | gallipoli
# Processing Record 41 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 6 | lieksa
# Processing Record 43 of Set 6 | saskylakh
# Processing Record 44 of Set 6 | flinders
# Processing Record 45 of Set 6 | poltavka
# Processing Record 46 of Set 6 | provideniya
# Processing Record 47 of Set 6 | moron
# Processing Record 48 of Set 6 | bolgatanga
# Processing Record 49 of Set 6 | ponta do sol
# Processing Record 50 of Set 6 | souillac
# Processing Record 1 of Set 7 | makakilo city
# Processing Record 2 of Set 7 | mattru
# Processing Record 3 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 7 | harbour breton
# Processing Record 5 of Set 7 | aksu
# Processing Record 6 of Set 7 | nagar
# Processing Record 7 of Set 7 | sisimiut
# Processing Record 8 of Set 7 | umm kaddadah
# Processing Record 9 of Set 7 | pisco
# Processing Record 10 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 11 of Set 7 | velyka pysarivka
# Processing Record 12 of Set 7 | urumqi
# Processing Record 13 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 7 | barra
# Processing Record 15 of Set 7 | gladstone
# Processing Record 16 of Set 7 | kargat
# Processing Record 17 of Set 7 | matane
# Processing Record 18 of Set 7 | pacific grove
# Processing Record 19 of Set 7 | mabaruma
# Processing Record 20 of Set 7 | grindavik
# Processing Record 21 of Set 7 | berdigestyakh
# Processing Record 22 of Set 7 | cidreira
# Processing Record 23 of Set 7 | silver city
# Processing Record 24 of Set 7 | derzhavinsk
# Processing Record 25 of Set 7 | maracacume
# Processing Record 26 of Set 7 | langsa
# Processing Record 27 of Set 7 | borovskoy
# Processing Record 28 of Set 7 | tadine
# Processing Record 29 of Set 7 | leningradskiy
# Processing Record 30 of Set 7 | nhulunbuy
# Processing Record 31 of Set 7 | noshiro
# Processing Record 32 of Set 7 | ancud
# Processing Record 33 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 7 | neuquen
# Processing Record 35 of Set 7 | qunduz
# Processing Record 36 of Set 7 | narsaq
# Processing Record 37 of Set 7 | kautokeino
# Processing Record 38 of Set 7 | dunedin
# Processing Record 39 of Set 7 | yar-sale
# Processing Record 40 of Set 7 | marquette
# Processing Record 41 of Set 7 | clyde river
# Processing Record 42 of Set 7 | khani
# Processing Record 43 of Set 7 | belaya gora
# Processing Record 44 of Set 7 | ambilobe
# Processing Record 45 of Set 7 | codrington
# Processing Record 46 of Set 7 | ahipara
# Processing Record 47 of Set 7 | komsomolskiy
# Processing Record 48 of Set 7 | bardiyah
# Processing Record 49 of Set 7 | poya
# Processing Record 50 of Set 7 | vicksburg
# Processing Record 1 of Set 8 | hellin
# Processing Record 2 of Set 8 | oktyabrskoye
# Processing Record 3 of Set 8 | taoudenni
# Processing Record 4 of Set 8 | shenjiamen
# Processing Record 5 of Set 8 | mount isa
# Processing Record 6 of Set 8 | roald
# Processing Record 7 of Set 8 | chaoyang
# Processing Record 8 of Set 8 | cabo san lucas
# Processing Record 9 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 8 | krumbach
# Processing Record 11 of Set 8 | jasper
# Processing Record 12 of Set 8 | cuamba
# Processing Record 13 of Set 8 | trinidad
# Processing Record 14 of Set 8 | maniitsoq
# Processing Record 15 of Set 8 | severo-kurilsk
# Processing Record 16 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 8 | itarema
# Processing Record 18 of Set 8 | lac du bonnet
# Processing Record 19 of Set 8 | shieli
# Processing Record 20 of Set 8 | touros
# Processing Record 21 of Set 8 | shu
# Processing Record 22 of Set 8 | tanabe
# Processing Record 23 of Set 8 | qui nhon
# Processing Record 24 of Set 8 | khairagarh
# Processing Record 25 of Set 8 | san-pedro
# Processing Record 26 of Set 8 | benghazi
# Processing Record 27 of Set 8 | mahebourg
# Processing Record 28 of Set 8 | sur
# Processing Record 29 of Set 8 | san cristobal
# Processing Record 30 of Set 8 | russell
# Processing Record 31 of Set 8 | lipin bor
# Processing Record 32 of Set 8 | araouane
# Processing Record 33 of Set 8 | anamur
# Processing Record 34 of Set 8 | harper
# Processing Record 35 of Set 8 | samarai
# Processing Record 36 of Set 8 | zapadnaya dvina
# Processing Record 37 of Set 8 | el alto
# Processing Record 38 of Set 8 | flin flon
# Processing Record 39 of Set 8 | pershotravneve
# Processing Record 40 of Set 8 | skibbereen
# Processing Record 41 of Set 8 | kurchum
# Processing Record 42 of Set 8 | orange
# Processing Record 43 of Set 8 | oak ridge
# Processing Record 44 of Set 8 | zonguldak
# Processing Record 45 of Set 8 | myitkyina
# Processing Record 46 of Set 8 | luena
# Processing Record 47 of Set 8 | garowe
# Processing Record 48 of Set 8 | guerrero negro
# Processing Record 49 of Set 8 | bambanglipuro
# Processing Record 50 of Set 8 | vangaindrano
# Processing Record 1 of Set 9 | moose factory
# Processing Record 2 of Set 9 | suntar
# Processing Record 3 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 4 of Set 9 | kavaratti
# Processing Record 5 of Set 9 | uchaly
# Processing Record 6 of Set 9 | newala
# Processing Record 7 of Set 9 | carballo
# Processing Record 8 of Set 9 | balikpapan
# Processing Record 9 of Set 9 | mudanjiang
# Processing Record 10 of Set 9 | darhan
# Processing Record 11 of Set 9 | rio grande
# Processing Record 12 of Set 9 | half moon bay
# Processing Record 13 of Set 9 | piacabucu
# Processing Record 14 of Set 9 | baghdad
# Processing Record 15 of Set 9 | kimbe
# Processing Record 16 of Set 9 | mutoko
# Processing Record 17 of Set 9 | bapatla
# Processing Record 18 of Set 9 | khandyga
# Processing Record 19 of Set 9 | tateyama
# Processing Record 20 of Set 9 | deputatskiy
# Processing Record 21 of Set 9 | lagos de moreno
# Processing Record 22 of Set 9 | inhambane
# Processing Record 23 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 24 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 9 | eyl
# Processing Record 26 of Set 9 | palmer
# Processing Record 27 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 28 of Set 9 | morinville
# Processing Record 29 of Set 9 | pangnirtung
# Processing Record 30 of Set 9 | rock island
# Processing Record 31 of Set 9 | severomuysk
# Processing Record 32 of Set 9 | olafsvik
# Processing Record 33 of Set 9 | jaisalmer
# Processing Record 34 of Set 9 | zhaozhou
# Processing Record 35 of Set 9 | tabuk
# Processing Record 36 of Set 9 | fort nelson
# Processing Record 37 of Set 9 | sao gabriel da cachoeira
# Processing Record 38 of Set 9 | ballina
# Processing Record 39 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 9 | taltal
# Processing Record 41 of Set 9 | paso de los toros
# Processing Record 42 of Set 9 | alekseyevsk
# Processing Record 43 of Set 9 | coihaique
# Processing Record 44 of Set 9 | laizhou
# Processing Record 45 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 46 of Set 9 | havoysund
# Processing Record 47 of Set 9 | karratha
# Processing Record 48 of Set 9 | bethanien
# Processing Record 49 of Set 9 | stephenville
# Processing Record 50 of Set 9 | bubaque
# Processing Record 1 of Set 10 | bhadrachalam
# Processing Record 2 of Set 10 | tancuayalab
# City not found. Skipping...
# Processing Record 3 of Set 10 | akhnur
# Processing Record 4 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 5 of Set 10 | cairns
# Processing Record 6 of Set 10 | garden city
# Processing Record 7 of Set 10 | kahului
# Processing Record 8 of Set 10 | te anau
# Processing Record 9 of Set 10 | hay river
# Processing Record 10 of Set 10 | uvat
# Processing Record 11 of Set 10 | canitas
# City not found. Skipping...
# Processing Record 12 of Set 10 | abyek
# Processing Record 13 of Set 10 | cayenne
# Processing Record 14 of Set 10 | ponnani
# Processing Record 15 of Set 10 | watsa
# Processing Record 16 of Set 10 | vao
# Processing Record 17 of Set 10 | mareeba
# Processing Record 18 of Set 10 | vung tau
# Processing Record 19 of Set 10 | werda
# Processing Record 20 of Set 10 | prince george
# Processing Record 21 of Set 10 | nakamura
# Processing Record 22 of Set 10 | ust-kuyga
# Processing Record 23 of Set 10 | alta
# Processing Record 24 of Set 10 | nyanguge
# Processing Record 25 of Set 10 | shirokiy
# Processing Record 26 of Set 10 | zhigalovo
# Processing Record 27 of Set 10 | posse
# Processing Record 28 of Set 10 | toguchin
# Processing Record 29 of Set 10 | kieta
# Processing Record 30 of Set 10 | taraz
# Processing Record 31 of Set 10 | asfi
# Processing Record 32 of Set 10 | junction city
# Processing Record 33 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 34 of Set 10 | chagoda
# Processing Record 35 of Set 10 | southbridge
# Processing Record 36 of Set 10 | bilibino
# Processing Record 37 of Set 10 | taybad
# Processing Record 38 of Set 10 | miraflores
# Processing Record 39 of Set 10 | pitimbu
# Processing Record 40 of Set 10 | zwettl
# Processing Record 41 of Set 10 | port moresby
# Processing Record 42 of Set 10 | kitimat
# Processing Record 43 of Set 10 | vila franca do campo
# Processing Record 44 of Set 10 | fort-shevchenko
# Processing Record 45 of Set 10 | krasnyy kut
# Processing Record 46 of Set 10 | eenhana
# Processing Record 47 of Set 10 | carlsbad
# Processing Record 48 of Set 10 | vernon
# Processing Record 49 of Set 10 | comodoro rivadavia
# Processing Record 50 of Set 10 | tura
# Processing Record 1 of Set 11 | teguldet
# Processing Record 2 of Set 11 | buckeye
# Processing Record 3 of Set 11 | talcher
# Processing Record 4 of Set 11 | marystown
# Processing Record 5 of Set 11 | constitucion
# Processing Record 6 of Set 11 | jati
# Processing Record 7 of Set 11 | rawson
# Processing Record 8 of Set 11 | elizabeth city
# Processing Record 9 of Set 11 | nepalganj
# City not found. Skipping...
# Processing Record 10 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 11 | avera
# Processing Record 12 of Set 11 | kelowna
# Processing Record 13 of Set 11 | tazovskiy
# Processing Record 14 of Set 11 | kilifi
# Processing Record 15 of Set 11 | sioux lookout
# Processing Record 16 of Set 11 | lahat
# Processing Record 17 of Set 11 | ranavav
# Processing Record 18 of Set 11 | carutapera
# Processing Record 19 of Set 11 | yerbogachen
# Processing Record 20 of Set 11 | kandrian
# Processing Record 21 of Set 11 | pemba
# Processing Record 22 of Set 11 | missoula
# Processing Record 23 of Set 11 | puerto suarez
# Processing Record 24 of Set 11 | lexington park
# Processing Record 25 of Set 11 | almeria
# Processing Record 26 of Set 11 | omsukchan
# Processing Record 27 of Set 11 | nsawam
# Processing Record 28 of Set 11 | kvitok
# Processing Record 29 of Set 11 | maumere
# Processing Record 30 of Set 11 | yueyang
# Processing Record 31 of Set 11 | farnham
# Processing Record 32 of Set 11 | hargeysa
# Processing Record 33 of Set 11 | coari
# Processing Record 34 of Set 11 | lucapa
# Processing Record 35 of Set 11 | mournies
# Processing Record 36 of Set 11 | izumo
# Processing Record 37 of Set 11 | mezen
# Processing Record 38 of Set 11 | bongandanga
# Processing Record 39 of Set 11 | marrakesh
# Processing Record 40 of Set 11 | vrani
# Processing Record 41 of Set 11 | bolu
# Processing Record 42 of Set 11 | lircay
# Processing Record 43 of Set 11 | nisia floresta
# Processing Record 44 of Set 11 | kudahuvadhoo
# Processing Record 45 of Set 11 | qaqortoq
# Processing Record 46 of Set 11 | ginda
# Processing Record 47 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 11 | sartell
# Processing Record 49 of Set 11 | bathsheba
# Processing Record 50 of Set 11 | asau
# Processing Record 1 of Set 12 | san lorenzo
# Processing Record 2 of Set 12 | atambua
# Processing Record 3 of Set 12 | south venice
# Processing Record 4 of Set 12 | mackay
# Processing Record 5 of Set 12 | pedro ii
# Processing Record 6 of Set 12 | bage
# Processing Record 7 of Set 12 | hofn
# Processing Record 8 of Set 12 | denton
# Processing Record 9 of Set 12 | la romana
# Processing Record 10 of Set 12 | abha
# Processing Record 11 of Set 12 | tessalit
# Processing Record 12 of Set 12 | fonte boa
# Processing Record 13 of Set 12 | lavumisa
# Processing Record 14 of Set 12 | hualmay
# Processing Record 15 of Set 12 | chapleau
# Processing Record 16 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 12 | abu samrah
# Processing Record 18 of Set 12 | kamiiso
# Processing Record 19 of Set 12 | kursumlija
# Processing Record 20 of Set 12 | grass valley
# Processing Record 21 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 22 of Set 12 | gemena
# Processing Record 23 of Set 12 | haldibari
# Processing Record 24 of Set 12 | along
# Processing Record 25 of Set 12 | ordzhonikidze
# Processing Record 26 of Set 12 | kamenka
# Processing Record 27 of Set 12 | pangody
# Processing Record 28 of Set 12 | picui
# Processing Record 29 of Set 12 | agua verde
# Processing Record 30 of Set 12 | mayo
# Processing Record 31 of Set 12 | kota belud
# Processing Record 32 of Set 12 | doha
# Processing Record 33 of Set 12 | seoul
# Processing Record 34 of Set 12 | ventspils
# Processing Record 35 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 37 of Set 12 | dukat
# Processing Record 38 of Set 12 | ostersund
# Processing Record 39 of Set 12 | fairbanks
# Processing Record 40 of Set 12 | nauta
# Processing Record 41 of Set 12 | banda aceh
# Processing Record 42 of Set 12 | sao filipe
# Processing Record 43 of Set 12 | jalingo
# Processing Record 44 of Set 12 | henties bay
# Processing Record 45 of Set 12 | caraquet
# Processing Record 46 of Set 12 | kabinda
# Processing Record 47 of Set 12 | itoman
# Processing Record 48 of Set 12 | ucluelet
# Processing Record 49 of Set 12 | puerto escondido
# Processing Record 50 of Set 12 | batemans bay
# Processing Record 1 of Set 13 | kaeo
# Processing Record 2 of Set 13 | westerland
# Processing Record 3 of Set 13 | kidal
# Processing Record 4 of Set 13 | staryy nadym
# Processing Record 5 of Set 13 | la ronge
# Processing Record 6 of Set 13 | vagur
# Processing Record 7 of Set 13 | jumla
# Processing Record 8 of Set 13 | iqaluit
# Processing Record 9 of Set 13 | north myrtle beach
# Processing Record 10 of Set 13 | teya
# Processing Record 11 of Set 13 | coahuayana
# Processing Record 12 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 13 | osmena
# Processing Record 14 of Set 13 | sinnamary
# Processing Record 15 of Set 13 | shimoda
# Processing Record 16 of Set 13 | takhatgarh
# Processing Record 17 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 18 of Set 13 | sokoto
# Processing Record 19 of Set 13 | cortez
# Processing Record 20 of Set 13 | chara
# Processing Record 21 of Set 13 | usinsk
# Processing Record 22 of Set 13 | santa cruz del sur
# Processing Record 23 of Set 13 | ivanteyevka
# Processing Record 24 of Set 13 | kasongo
# Processing Record 25 of Set 13 | dakar
# Processing Record 26 of Set 13 | vaitape
# Processing Record 27 of Set 13 | berlevag
# Processing Record 28 of Set 13 | shihezi
# Processing Record 29 of Set 13 | ouadda
# Processing Record 30 of Set 13 | geraldton
# Processing Record 31 of Set 13 | ushirombo
# Processing Record 32 of Set 13 | saint-francois
# Processing Record 33 of Set 13 | montanha
# Processing Record 34 of Set 13 | maragogi
# Processing Record 35 of Set 13 | kahta
# Processing Record 36 of Set 13 | lae
# Processing Record 37 of Set 13 | almaznyy
# Processing Record 38 of Set 13 | grand island
# Processing Record 39 of Set 13 | verkh-usugli
# Processing Record 40 of Set 13 | yulara
# Processing Record 41 of Set 13 | makubetsu
# Processing Record 42 of Set 13 | san patricio
# Processing Record 43 of Set 13 | rio gallegos
# Processing Record 44 of Set 13 | warri
# Processing Record 45 of Set 13 | richards bay
# Processing Record 46 of Set 13 | pontes e lacerda
# Processing Record 47 of Set 13 | anchovy
# Processing Record 48 of Set 13 | celestun
# Processing Record 49 of Set 13 | aqtobe
# Processing Record 50 of Set 13 | waddan
# Processing Record 1 of Set 14 | edgewater
# Processing Record 2 of Set 14 | merrill
# Processing Record 3 of Set 14 | camabatela
# Processing Record 4 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 14 | huarmey
# Processing Record 6 of Set 14 | nuuk
# Processing Record 7 of Set 14 | victor harbor
# Processing Record 8 of Set 14 | uribia
# Processing Record 9 of Set 14 | boaco
# Processing Record 10 of Set 14 | nieuw amsterdam
# Processing Record 11 of Set 14 | camacha
# Processing Record 12 of Set 14 | lerwick
# Processing Record 13 of Set 14 | dalvik
# Processing Record 14 of Set 14 | fallon
# Processing Record 15 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 16 of Set 14 | qarqin
# Processing Record 17 of Set 14 | dingzhou
# Processing Record 18 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 14 | praia
# Processing Record 20 of Set 14 | karpogory
# Processing Record 21 of Set 14 | tecolutla
# Processing Record 22 of Set 14 | golaesti
# Processing Record 23 of Set 14 | kemijarvi
# Processing Record 24 of Set 14 | hare bay
# Processing Record 25 of Set 14 | newport
# Processing Record 26 of Set 14 | holden
# Processing Record 27 of Set 14 | homer
# Processing Record 28 of Set 14 | sribne
# Processing Record 29 of Set 14 | khonsa
# Processing Record 30 of Set 14 | martapura
# Processing Record 31 of Set 14 | bentiu
# Processing Record 32 of Set 14 | sao jose de ribamar
# Processing Record 33 of Set 14 | pacifica
# Processing Record 34 of Set 14 | pajacuaran
# Processing Record 35 of Set 14 | cap-aux-meules
# Processing Record 36 of Set 14 | porto novo
# Processing Record 37 of Set 14 | adrar
# Processing Record 38 of Set 14 | ciudad bolivar
# Processing Record 39 of Set 14 | plymouth
# Processing Record 40 of Set 14 | duz
# City not found. Skipping...
# Processing Record 41 of Set 14 | poso
# Processing Record 42 of Set 14 | manyana
# Processing Record 43 of Set 14 | nemuro
# Processing Record 44 of Set 14 | saravan
# Processing Record 45 of Set 14 | liepaja
# Processing Record 46 of Set 14 | ibotirama
# Processing Record 47 of Set 14 | guaymas
# Processing Record 48 of Set 14 | northam
# Processing Record 49 of Set 14 | chumikan
# Processing Record 50 of Set 14 | saint george
# Processing Record 1 of Set 15 | nehe
# Processing Record 2 of Set 15 | malchin
# Processing Record 3 of Set 15 | otaru
# Processing Record 4 of Set 15 | saint-malo
# Processing Record 5 of Set 15 | phanom sarakham
# Processing Record 6 of Set 15 | new castle
# Processing Record 7 of Set 15 | svetlaya
# Processing Record 8 of Set 15 | nagaur
# Processing Record 9 of Set 15 | kurilsk
# Processing Record 10 of Set 15 | bontang
# Processing Record 11 of Set 15 | new port richey
# Processing Record 12 of Set 15 | parabel
# Processing Record 13 of Set 15 | keetmanshoop
# Processing Record 14 of Set 15 | isangel
# Processing Record 15 of Set 15 | buala
# Processing Record 16 of Set 15 | tilichiki
# Processing Record 17 of Set 15 | padre paraiso
# Processing Record 18 of Set 15 | bela
# Processing Record 19 of Set 15 | maua
# Processing Record 20 of Set 15 | ilheus
# Processing Record 21 of Set 15 | dirba
# Processing Record 22 of Set 15 | qasigiannguit
# Processing Record 23 of Set 15 | standerton
# Processing Record 24 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 15 | ust-ilimsk
# Processing Record 26 of Set 15 | itupiranga
# Processing Record 27 of Set 15 | xuanhua
# Processing Record 28 of Set 15 | praya
# Processing Record 29 of Set 15 | chama
# Processing Record 30 of Set 15 | hamcearca
# Processing Record 31 of Set 15 | patacamaya
# Processing Record 32 of Set 15 | kuching
# Processing Record 33 of Set 15 | chimbote
# Processing Record 34 of Set 15 | ino
# Processing Record 35 of Set 15 | arlit
# Processing Record 36 of Set 15 | atar
# Processing Record 37 of Set 15 | alice springs
# Processing Record 38 of Set 15 | daxian
# City not found. Skipping...
# Processing Record 39 of Set 15 | dzhida
# Processing Record 40 of Set 15 | sabang
# Processing Record 41 of Set 15 | nakhon si thammarat
# Processing Record 42 of Set 15 | santa isabel
# Processing Record 43 of Set 15 | humberto de campos
# Processing Record 44 of Set 15 | salalah
# Processing Record 45 of Set 15 | bulgan
# Processing Record 46 of Set 15 | sao miguel do araguaia
# Processing Record 47 of Set 15 | torrevieja
# Processing Record 48 of Set 15 | necochea
# Processing Record 49 of Set 15 | carbonia
# Processing Record 50 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 1 of Set 16 | nanchang
# Processing Record 2 of Set 16 | pontal do parana
# Processing Record 3 of Set 16 | jining
# Processing Record 4 of Set 16 | vyshkov
# Processing Record 5 of Set 16 | manadhoo
# Processing Record 6 of Set 16 | cam ranh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 700

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0        Ushuaia -54.8000  -68.3000     44.26       broken clouds        57
# 1         Tiznit  29.5833   -9.5000     67.64       broken clouds        25
# 2  Mar Del Plata -38.0023  -57.5575     80.10           clear sky        61
# 3          Airai  -8.9266  125.4092     60.66       moderate rain        89
# 4  Les Escoumins  48.1111  -69.0236     30.76     overcast clouds        83
# 5   Vila Do Maio  15.1333  -23.2167     72.39           clear sky        80
# 6     Nikolskoye  59.7035   30.7861     22.89     overcast clouds        98
# 7         Laguna  38.4210 -121.4238     62.47           clear sky        28
# 8          Vaini -21.2000 -175.2000     86.16    scattered clouds        74
# 9      Cape Town -33.9258   18.4232     66.11    scattered clouds        88
#
#    Cloudiness  Wind Speed Country                 Date
# 0          75       25.32      AR  2022-02-02 22:23:20
# 1          81        6.64      MA  2022-02-02 22:24:50
# 2           0        6.91      AR  2022-02-02 22:18:08
# 3         100        2.35      TL  2022-02-02 22:22:17
# 4         100       12.03      CA  2022-02-02 22:24:50
# 5           1       15.28      CV  2022-02-02 22:24:51
# 6          99        1.10      RU  2022-02-02 22:22:12
# 7           0        8.99      US  2022-02-02 22:22:45
# 8          40        5.75      TO  2022-02-02 22:17:45
# 9          40        3.00      ZA  2022-02-02 22:23:22

# %%
new_column_city_data = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_city_data]
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia      AR -54.8000  -68.3000     44.26        57          75
# 1         Tiznit      MA  29.5833   -9.5000     67.64        25          81
# 2  Mar Del Plata      AR -38.0023  -57.5575     80.10        61           0
# 3          Airai      TL  -8.9266  125.4092     60.66        89         100
# 4  Les Escoumins      CA  48.1111  -69.0236     30.76        83         100
#
#    Wind Speed Current Description
# 0       25.32       broken clouds
# 1        6.64       broken clouds
# 2        6.91           clear sky
# 3        2.35       moderate rain
# 4       12.03     overcast clouds

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
